# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
x = [1,2,3,4,5]
y = [372.25,44.75,1.25,0,0]
ax.bar(x,y)
ax.set_title("Number of Unique Paths by Length Averaged over 2015-16 to 2018-19 NBA Season")
ax.set_xlabel("Number of Games After Analyzed")
ax.set_ylabel("Number of Unique Paths")
plt.show()
